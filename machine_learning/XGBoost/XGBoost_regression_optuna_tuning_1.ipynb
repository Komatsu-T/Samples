# %% [markdown]
# # CatBoost Regression sample
# ### Simple optuna tuning

# %% [markdown]
# ### Import libraries

# %%
# !pip install shap
# !pip install optuna
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.12/dist-packages (0.50.0)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from shap) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from shap) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.12/dist-packages (from shap) (25.0)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from shap) (4.15.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.45)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from scipy.stats import loguniform
from tqdm import tqdm

import xgboost as xgb
import optuna
import shap

# %% [markdown]
# ### Dataset

# %%
# ----------------------------------------------
# Create sample dataset
# ----------------------------------------------

# Dataset
housing = fetch_california_housing()
housing_data = pd.DataFrame(data = housing.data, columns = housing.feature_names)
housing_data['target'] = housing.target
housing_data.reset_index(inplace = True, drop = True)

# Functions
def make_correlation_category(
        x_grid: list,
        y_grid: list,
        x_feature_name: str,
        y_feature_name: str,
        datset: pd.core.frame.DataFrame,
        catefory_names = list('ABCDEFGHIJKLMNOPQLSTUVWXYZ')
):
    i = 0
    index_list = []
    category_list = []
    for y1, y2 in zip(y_grid[:-1], y_grid[1:]):
        for x1, x2 in zip(x_grid[:-1], x_grid[1:]):
            temp_data = datset[(x1<=datset[x_feature_name]) & (datset[x_feature_name]<x2) & (y1<=datset[y_feature_name]) & (datset[y_feature_name]<y2)].copy()
            if temp_data.shape[0] > 0:
                index_list += temp_data.index.tolist()
                category_list += [catefory_names[i] for k in range(temp_data.shape[0])]
                i += 1
    return np.array(category_list)[np.argsort(np.array(index_list))]

# Make categorical features 1
housing_data['Area_category'] = make_correlation_category(
    x_grid = [32, 34, 36, 38, 40, 44],
    y_grid = [-126, -122, -120, -118, -116, -114],
    x_feature_name = 'Latitude',
    y_feature_name = 'Longitude',
    datset = housing_data,
)

# Make categorical features 2
housing_data['Room_num_category'] = make_correlation_category(
    x_grid = [0, 5, 10, 40],
    y_grid = [0, 20, 40, 170],
    x_feature_name = 'AveBedrms',
    y_feature_name = 'AveRooms',
    datset = housing_data,
)

# %%
housing_data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  target Area_category Room_num_category
# 0        -122.23   4.526             A                 A
# 1        -122.22   3.585             A                 A
# 2        -122.24   3.521             A                 A
# 3        -122.25   3.413             A                 A
# 4        -122.25   3.422             A                 A
# ...          ...     ...           ...               ...
# 20635    -121.09   0.781             F                 A
# 20636    -121.21   0.771             F                 A
# 20637    -121.22   0.923             F                 A
# 20638    -121.32   0.847             F                 A
# 20639    -121.24   0.894             F                 A
#
# [20640 rows x 11 columns]

# %% [markdown]
# ### Train-test split

# %%
train_valid_data, test_data = train_test_split(housing_data, test_size=0.2, shuffle=True)
print(f'Train & validation data shape: {train_valid_data.shape}')
print(f'Test data shape: {test_data.shape}')
# Out:
# Train & validation data shape: (16512, 11)
# Test data shape: (4128, 11)

# %% [markdown]
# ### Category encoding

# %%
# ----------------------------------------------
# Categorical encoding
# ----------------------------------------------

categorical_featues = ['Area_category', 'Room_num_category']
categorical_encoders = {}
for col in categorical_featues:
    enc = LabelEncoder()
    enc.fit(train_valid_data[col].unique())
    train_valid_data[col+'_encoded'] = enc.transform(train_valid_data[col])
    categorical_encoders[col] = enc

# %% [markdown]
# ### Tuning hyper-parameters

# %%
# ----------------------------------------------
# Hyper parameter tuning by optuna
# ----------------------------------------------

# Feature names
feature_names = ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude', 'Area_category_encoded', 'Room_num_category_encoded']
target_name = ['target']

# Trial function
def objective(trial):

    # Parameters
    param = {
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_float('gamma', 0, 5),
    }

    # Training
    model = xgb.XGBRegressor(**param)
    score = cross_val_score(model, train_valid_data[feature_names], train_valid_data[target_name], cv=3, scoring='neg_mean_squared_error').mean()
    return score

# Tuning
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
# [I 2026-01-12 02:40:12,183] A new study created in memory with name: no-name-b3246d93-5db8-4872-957c-d9032bf680c0
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-01-12 02:40:20,353] Trial 0 finished with value: -0.25487607220808667 and parameters: {'max_depth': 5, 'learning_rate': 0.03140409359478366, 'n_estimators': 287, 'subsample': 0.5709005888118791, 'colsample_bytree': 0.7129236168870785, 'min_child_weight': 2, 'gamma': 2.7905230536039145}. Best is trial 0 with value: -0.25487607220808667.
# [I 2026-01-12 02:40:23,914] Trial 1 finished with value: -0.4220438102881114 and parameters: {'max_depth': 3, 'learning_rate': 0.01858308543523291, 'n_estimators': 132, 'subsample': 0.8641558807631418, 'colsample_bytree': 0.8651100263220223, 'min_child_weight': 9, 'gamma': 1.736046193991938}. Best is trial 0 with value: -0.25487607220808667.
# [I 2026-01-12 02:40:31,484] Trial 2 finished with value: -0.2157127857208252 and parameters: {'max_depth': 10, 'learning_rate': 0.07655002054700573, 'n_estimators': 137, 'subsample': 0.9589808591328669, 'colsample_bytree': 0.60512433239029, 'min_child_weight': 1, 'gamma': 0.88453760374189}. Best is trial 2 with value: -0.2157127857208252.
# [I 2026-01-12 02:40:38,646] Trial 3 finished with value: -0.21628894408543906 and parameters: {'max_depth': 10, 'learning_rate': 0.04402865283023243, 'n_estimators': 340, 'subsample': 0.8832717083917646, 'colsample_bytree': 0.5195899839527025, 'min_child_weight': 2, 'gamma': 1.2112104903959076}. Best is trial 2 with value: -0.2157127857208252.
# [I 2026-01-12 02:40:41,987] Trial 4 finished with value: -0.23042798539002737 and parameters: {'max_depth': 8, 'learning_rate': 0.05707235405417701, 'n_estimators': 572, 'subsample': 0.9636174011567014, 'colsample_bytree': 0.8256984258514997, 'min_child_weight': 2, 'gamma': 1.0692438884413868}. Best is trial 2 with value: -0.2157127857208252.
# [I 2026-01-12 02:40:43,603] Trial 5 finished with value: -0.28336183230082196 and parameters: {'max_depth': 3, 'learning_rate': 0.05886848958836905, 'n_estimators': 594, 'subsample': 0.6277083903211693, 'colsample_bytree': 0.7686387748639963, 'min_child_weight': 6, 'gamma': 4.743512087238685}. Best is trial 2 with value: -0.2157127857208252.
# [I 2026-01-12 02:40:44,991] Trial 6 finished with value: -0.27911556760470074 and parameters: {'max_depth': 3, 'learning_rate': 0.03424589770488759, 'n_estimators': 630, 'subsample': 0.5594393766954247, 'colsample_bytree': 0.966705278247719, 'min_child_weight': 5, 'gamma': 3.6975258440500944}. Best is trial 2 with value: -0.2157127857208252.
# [I 2026-01-12 02:40:46,537] Trial 7 finished with value: -0.2613105773925781 and parameters: {'max_depth': 5, 'learning_rate': 0.08077642458867415, 'n_estimators': 861, 'subsample': 0.8081228175450026, 'colsample_bytree': 0.9644813068065439, 'min_child_weight': 4, 'gamma': 3.5872515200360775}. Best is trial 2 with value: -0.2157127857208252.
# [I 2026-01-12 02:40:50,322] Trial 8 finished with value: -0.22349379460016885 and parameters: {'max_depth': 9, 'learning_rate': 0.012804225847527944, 'n_estimators': 443, 'subsample': 0.7534700621250898, 'colsample_bytree': 0.5023518702012029, 'min_child_weight': 5, 'gamma': 1.5401706345467192}. Best is trial 2 with value: -0.2157127857208252.
# [I 2026-01-12 02:40:52,120] Trial 9 finished with value: -0.2105365345875422 and parameters: {'max_depth': 7, 'learning_rate': 0.07473042628415659, 'n_estimators': 196, 'subsample': 0.6954656916021285, 'colsample_bytree': 0.6333840495337479, 'min_child_weight': 1, 'gamma': 0.24755321318231494}. Best is trial 9 with value: -0.2105365345875422.
# [I 2026-01-12 02:40:57,146] Trial 10 finished with value: -0.2107586165269216 and parameters: {'max_depth': 7, 'learning_rate': 0.09942770799675307, 'n_estimators': 947, 'subsample': 0.6745773182700616, 'colsample_bytree': 0.6593517025522024, 'min_child_weight': 10, 'gamma': 0.21386471518823402}. Best is trial 9 with value: -0.2105365345875422.
# [I 2026-01-12 02:41:00,372] Trial 11 finished with value: -0.21208305656909943 and parameters: {'max_depth': 7, 'learning_rate': 0.09635128364809623, 'n_estimators': 966, 'subsample': 0.6676859697317653, 'colsample_bytree': 0.6535834602835517, 'min_child_weight': 10, 'gamma': 0.2137944949273055}. Best is trial 9 with value: -0.2105365345875422.
# [I 2026-01-12 02:41:03,349] Trial 12 finished with value: -0.21081345776716867 and parameters: {'max_depth': 6, 'learning_rate': 0.09955188280883938, 'n_estimators': 784, 'subsample': 0.6982600768249179, 'colsample_bytree': 0.617529789079867, 'min_child_weight': 8, 'gamma': 0.19378980866731846}. Best is trial 9 with value: -0.2105365345875422.
# [I 2026-01-12 02:41:04,770] Trial 13 finished with value: -0.2328332563241323 and parameters: {'max_depth': 7, 'learning_rate': 0.07789938172447167, 'n_estimators': 781, 'subsample': 0.7416881524234135, 'colsample_bytree': 0.6877298852433587, 'min_child_weight': 7, 'gamma': 2.290768061280417}. Best is trial 9 with value: -0.2105365345875422.
# [I 2026-01-12 02:41:10,144] Trial 14 finished with value: -0.20924715201059976 and parameters: {'max_depth': 8, 'learning_rate': 0.08748953249894513, 'n_estimators': 983, 'subsample': 0.611282893408408, 'colsample_bytree': 0.578546727206405, 'min_child_weight': 10, 'gamma': 0.20712648871134845}. Best is trial 14 with value: -0.20924715201059976.
# [I 2026-01-12 02:41:11,760] Trial 15 finished with value: -0.21549401680628458 and parameters: {'max_depth': 8, 'learning_rate': 0.07011268085298887, 'n_estimators': 435, 'subsample': 0.5312820583761694, 'colsample_bytree': 0.570184368779122, 'min_child_weight': 4, 'gamma': 0.7005946748581167}. Best is trial 14 with value: -0.20924715201059976.
# [I 2026-01-12 02:41:13,156] Trial 16 finished with value: -0.2277620236078898 and parameters: {'max_depth': 8, 'learning_rate': 0.08723506003024548, 'n_estimators': 734, 'subsample': 0.606734337380709, 'colsample_bytree': 0.5498362592464506, 'min_child_weight': 8, 'gamma': 2.0757276974884493}. Best is trial 14 with value: -0.20924715201059976.
# [I 2026-01-12 02:41:14,427] Trial 17 finished with value: -0.2277202010154724 and parameters: {'max_depth': 5, 'learning_rate': 0.06728820867597604, 'n_estimators': 244, 'subsample': 0.511234661019272, 'colsample_bytree': 0.7567501520207137, 'min_child_weight': 3, 'gamma': 0.6089216397954924}. Best is trial 14 with value: -0.20924715201059976.
# [I 2026-01-12 02:41:15,468] Trial 18 finished with value: -0.2311605860789617 and parameters: {'max_depth': 9, 'learning_rate': 0.08558186995124997, 'n_estimators': 471, 'subsample': 0.7356725216269309, 'colsample_bytree': 0.5803570182625787, 'min_child_weight': 7, 'gamma': 2.9762243214609425}. Best is trial 14 with value: -0.20924715201059976.
# [I 2026-01-12 02:41:22,318] Trial 19 finished with value: -0.20728221535682678 and parameters: {'max_depth': 6, 'learning_rate': 0.04946345626741292, 'n_estimators': 675, 'subsample': 0.614584575548643, 'colsample_bytree': 0.636634242058881, 'min_child_weight': 1, 'gamma': 0.013171901389613883}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:41:24,145] Trial 20 finished with value: -0.23070314029852548 and parameters: {'max_depth': 6, 'learning_rate': 0.04528950410757276, 'n_estimators': 690, 'subsample': 0.6434983821404047, 'colsample_bytree': 0.7173938617652524, 'min_child_weight': 6, 'gamma': 1.499134857017213}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:41:30,115] Trial 21 finished with value: -0.2098881403605143 and parameters: {'max_depth': 6, 'learning_rate': 0.06616142757843829, 'n_estimators': 879, 'subsample': 0.5922897473635989, 'colsample_bytree': 0.628232131899474, 'min_child_weight': 1, 'gamma': 0.06311148511274572}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:41:34,956] Trial 22 finished with value: -0.219424436489741 and parameters: {'max_depth': 4, 'learning_rate': 0.048322330735993756, 'n_estimators': 878, 'subsample': 0.5909720735370448, 'colsample_bytree': 0.54330783258378, 'min_child_weight': 3, 'gamma': 0.03930249475446313}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:41:37,577] Trial 23 finished with value: -0.2154281089703242 and parameters: {'max_depth': 6, 'learning_rate': 0.06221997812810175, 'n_estimators': 993, 'subsample': 0.5548076904639502, 'colsample_bytree': 0.5887379330249017, 'min_child_weight': 1, 'gamma': 0.6102610937399446}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:41:39,911] Trial 24 finished with value: -0.2201788673798243 and parameters: {'max_depth': 6, 'learning_rate': 0.08819534718613567, 'n_estimators': 876, 'subsample': 0.5019825363411567, 'colsample_bytree': 0.6650296490196981, 'min_child_weight': 3, 'gamma': 0.6312052675616885}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:41:42,710] Trial 25 finished with value: -0.21930734813213348 and parameters: {'max_depth': 4, 'learning_rate': 0.050480436857183, 'n_estimators': 810, 'subsample': 0.6095983282388584, 'colsample_bytree': 0.6201977757606718, 'min_child_weight': 4, 'gamma': 0.017210509588377516}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:41:47,550] Trial 26 finished with value: -0.2227763533592224 and parameters: {'max_depth': 9, 'learning_rate': 0.03733731481295394, 'n_estimators': 677, 'subsample': 0.6546357549707045, 'colsample_bytree': 0.8013808300044611, 'min_child_weight': 2, 'gamma': 1.178150713538478}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:41:49,165] Trial 27 finished with value: -0.24279546240965524 and parameters: {'max_depth': 8, 'learning_rate': 0.0641424550748981, 'n_estimators': 874, 'subsample': 0.7998631401082202, 'colsample_bytree': 0.7029955587998533, 'min_child_weight': 9, 'gamma': 4.704632921281867}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:41:53,037] Trial 28 finished with value: -0.21828659375508627 and parameters: {'max_depth': 5, 'learning_rate': 0.02525549652939234, 'n_estimators': 934, 'subsample': 0.582751169527873, 'colsample_bytree': 0.5497333743398809, 'min_child_weight': 1, 'gamma': 0.4652615809046769}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:41:54,273] Trial 29 finished with value: -0.2481943815946579 and parameters: {'max_depth': 5, 'learning_rate': 0.0528272468665112, 'n_estimators': 501, 'subsample': 0.6246600189233095, 'colsample_bytree': 0.7233988238831741, 'min_child_weight': 3, 'gamma': 2.6587926676693576}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:41:55,564] Trial 30 finished with value: -0.2592058579126994 and parameters: {'max_depth': 4, 'learning_rate': 0.06920845455394989, 'n_estimators': 745, 'subsample': 0.5522637496668461, 'colsample_bytree': 0.6812640939566356, 'min_child_weight': 2, 'gamma': 3.1887247396782743}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:41:59,257] Trial 31 finished with value: -0.21232942243417105 and parameters: {'max_depth': 7, 'learning_rate': 0.07331787275011362, 'n_estimators': 360, 'subsample': 0.7017167972236319, 'colsample_bytree': 0.608927654971628, 'min_child_weight': 1, 'gamma': 0.45008622820795463}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:01,847] Trial 32 finished with value: -0.20819804072380066 and parameters: {'max_depth': 7, 'learning_rate': 0.08111092701833264, 'n_estimators': 237, 'subsample': 0.7101135707896865, 'colsample_bytree': 0.6180589993449104, 'min_child_weight': 1, 'gamma': 0.00571305336670008}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:03,622] Trial 33 finished with value: -0.22364487747351328 and parameters: {'max_depth': 6, 'learning_rate': 0.09245764698743897, 'n_estimators': 922, 'subsample': 0.7739698958788477, 'colsample_bytree': 0.6455037280101342, 'min_child_weight': 2, 'gamma': 0.8882591020275612}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:14,332] Trial 34 finished with value: -0.21235843499501547 and parameters: {'max_depth': 8, 'learning_rate': 0.08288846928632783, 'n_estimators': 999, 'subsample': 0.5746931223329881, 'colsample_bytree': 0.5788377749363839, 'min_child_weight': 1, 'gamma': 0.017896486663387542}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:15,579] Trial 35 finished with value: -0.22281337281068167 and parameters: {'max_depth': 7, 'learning_rate': 0.09104543389282563, 'n_estimators': 535, 'subsample': 0.8648926816374131, 'colsample_bytree': 0.5339463031946372, 'min_child_weight': 2, 'gamma': 0.8832098210271306}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:16,824] Trial 36 finished with value: -0.23717590669790903 and parameters: {'max_depth': 6, 'learning_rate': 0.05818907588126447, 'n_estimators': 390, 'subsample': 0.7222198972130355, 'colsample_bytree': 0.8706171700223839, 'min_child_weight': 1, 'gamma': 1.8908297156109655}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:18,175] Trial 37 finished with value: -0.22649904092152914 and parameters: {'max_depth': 9, 'learning_rate': 0.041720475468727036, 'n_estimators': 124, 'subsample': 0.6398540052187348, 'colsample_bytree': 0.5966817398644251, 'min_child_weight': 1, 'gamma': 1.3992992243214386}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:19,419] Trial 38 finished with value: -0.22561071813106537 and parameters: {'max_depth': 8, 'learning_rate': 0.07968334729257145, 'n_estimators': 304, 'subsample': 0.9973475348133847, 'colsample_bytree': 0.7326747637781388, 'min_child_weight': 9, 'gamma': 0.9702931824295303}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:22,595] Trial 39 finished with value: -0.208157608906428 and parameters: {'max_depth': 10, 'learning_rate': 0.062497288178576124, 'n_estimators': 635, 'subsample': 0.6042015154477098, 'colsample_bytree': 0.5126864733129128, 'min_child_weight': 2, 'gamma': 0.35132842884024573}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:26,620] Trial 40 finished with value: -0.2104323754707972 and parameters: {'max_depth': 10, 'learning_rate': 0.05534080617092123, 'n_estimators': 599, 'subsample': 0.8236315124676986, 'colsample_bytree': 0.5255873895587202, 'min_child_weight': 2, 'gamma': 0.5130708611903992}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:29,370] Trial 41 finished with value: -0.21068503459294638 and parameters: {'max_depth': 10, 'learning_rate': 0.06292657015182553, 'n_estimators': 657, 'subsample': 0.6066416824763883, 'colsample_bytree': 0.5095050706675103, 'min_child_weight': 1, 'gamma': 0.39096244526398855}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:32,129] Trial 42 finished with value: -0.20836228132247925 and parameters: {'max_depth': 9, 'learning_rate': 0.07465836877050475, 'n_estimators': 826, 'subsample': 0.6736806154442165, 'colsample_bytree': 0.5580600474940625, 'min_child_weight': 2, 'gamma': 0.31838050686607533}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:34,729] Trial 43 finished with value: -0.20857151846090952 and parameters: {'max_depth': 9, 'learning_rate': 0.07359264542125857, 'n_estimators': 826, 'subsample': 0.6672626756458219, 'colsample_bytree': 0.5668217653428049, 'min_child_weight': 2, 'gamma': 0.37081767990065834}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:38,599] Trial 44 finished with value: -0.21405594050884247 and parameters: {'max_depth': 10, 'learning_rate': 0.07375863021112446, 'n_estimators': 723, 'subsample': 0.6695058176015215, 'colsample_bytree': 0.5649531322000001, 'min_child_weight': 2, 'gamma': 0.8080902227825155}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:40,412] Trial 45 finished with value: -0.2169368714094162 and parameters: {'max_depth': 9, 'learning_rate': 0.07629621115647725, 'n_estimators': 825, 'subsample': 0.686785889149974, 'colsample_bytree': 0.5076119210463184, 'min_child_weight': 3, 'gamma': 1.1053355302203176}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:43,162] Trial 46 finished with value: -0.21003281573454538 and parameters: {'max_depth': 10, 'learning_rate': 0.05964859860873129, 'n_estimators': 631, 'subsample': 0.7134574535542899, 'colsample_bytree': 0.5501590155361026, 'min_child_weight': 2, 'gamma': 0.3564814275111284}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:45,108] Trial 47 finished with value: -0.23338300486405691 and parameters: {'max_depth': 9, 'learning_rate': 0.07182166380778009, 'n_estimators': 587, 'subsample': 0.6489777317783614, 'colsample_bytree': 0.9092644602044877, 'min_child_weight': 4, 'gamma': 1.3122161319834202}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:45,804] Trial 48 finished with value: -0.23656564950942993 and parameters: {'max_depth': 10, 'learning_rate': 0.08209391958304171, 'n_estimators': 176, 'subsample': 0.7638397170107468, 'colsample_bytree': 0.5990996142687893, 'min_child_weight': 3, 'gamma': 4.464718985402712}. Best is trial 19 with value: -0.20728221535682678.
# [I 2026-01-12 02:42:51,495] Trial 49 finished with value: -0.20454108218352 and parameters: {'max_depth': 9, 'learning_rate': 0.04043014353252638, 'n_estimators': 538, 'subsample': 0.6785188674252507, 'colsample_bytree': 0.5245897624314723, 'min_child_weight': 5, 'gamma': 0.24634769912631505}. Best is trial 49 with value: -0.20454108218352.
# [I 2026-01-12 02:42:53,559] Trial 50 finished with value: -0.21924922366937002 and parameters: {'max_depth': 9, 'learning_rate': 0.03221170320360262, 'n_estimators': 525, 'subsample': 0.6823194739979624, 'colsample_bytree': 0.5169911109687124, 'min_child_weight': 5, 'gamma': 1.6147022679364484}. Best is trial 49 with value: -0.20454108218352.
# [I 2026-01-12 02:42:58,503] Trial 51 finished with value: -0.20726514359315237 and parameters: {'max_depth': 9, 'learning_rate': 0.027795220400407994, 'n_estimators': 766, 'subsample': 0.7233602868294283, 'colsample_bytree': 0.5008654190772395, 'min_child_weight': 2, 'gamma': 0.3096648139063499}. Best is trial 49 with value: -0.20454108218352.
# [I 2026-01-12 02:43:04,087] Trial 52 finished with value: -0.21101966996987662 and parameters: {'max_depth': 9, 'learning_rate': 0.02530894307593109, 'n_estimators': 766, 'subsample': 0.7309499993765447, 'colsample_bytree': 0.5308876185407478, 'min_child_weight': 2, 'gamma': 0.7146149139463931}. Best is trial 49 with value: -0.20454108218352.
# [I 2026-01-12 02:43:08,303] Trial 53 finished with value: -0.2044895589351654 and parameters: {'max_depth': 10, 'learning_rate': 0.0386987555951724, 'n_estimators': 694, 'subsample': 0.6323239532533825, 'colsample_bytree': 0.5055527724904894, 'min_child_weight': 6, 'gamma': 0.2816942034385525}. Best is trial 53 with value: -0.2044895589351654.
# [I 2026-01-12 02:43:13,748] Trial 54 finished with value: -0.20413640141487122 and parameters: {'max_depth': 10, 'learning_rate': 0.03805686679307337, 'n_estimators': 718, 'subsample': 0.784528854365968, 'colsample_bytree': 0.5019574118288259, 'min_child_weight': 6, 'gamma': 0.16870426338955335}. Best is trial 54 with value: -0.20413640141487122.
# [I 2026-01-12 02:43:20,788] Trial 55 finished with value: -0.20561316112677255 and parameters: {'max_depth': 10, 'learning_rate': 0.026342477016071817, 'n_estimators': 703, 'subsample': 0.914511928430951, 'colsample_bytree': 0.504383699018329, 'min_child_weight': 6, 'gamma': 0.21765927817860445}. Best is trial 54 with value: -0.20413640141487122.
# [I 2026-01-12 02:43:29,914] Trial 56 finished with value: -0.20482241610685983 and parameters: {'max_depth': 10, 'learning_rate': 0.026070432985785, 'n_estimators': 697, 'subsample': 0.9275929449006884, 'colsample_bytree': 0.5023387061768001, 'min_child_weight': 6, 'gamma': 0.19677666314532283}. Best is trial 54 with value: -0.20413640141487122.
# [I 2026-01-12 02:43:35,277] Trial 57 finished with value: -0.2052199294169744 and parameters: {'max_depth': 10, 'learning_rate': 0.026784967582637556, 'n_estimators': 714, 'subsample': 0.9220189908783082, 'colsample_bytree': 0.50109183313076, 'min_child_weight': 6, 'gamma': 0.22951063760240767}. Best is trial 54 with value: -0.20413640141487122.
# [I 2026-01-12 02:43:44,405] Trial 58 finished with value: -0.21117938061555228 and parameters: {'max_depth': 10, 'learning_rate': 0.011358763605108353, 'n_estimators': 716, 'subsample': 0.9182912584907105, 'colsample_bytree': 0.5308416248185431, 'min_child_weight': 6, 'gamma': 0.7169725862919334}. Best is trial 54 with value: -0.20413640141487122.
# [I 2026-01-12 02:43:54,542] Trial 59 finished with value: -0.20447016259034476 and parameters: {'max_depth': 10, 'learning_rate': 0.017694913215949286, 'n_estimators': 577, 'subsample': 0.9053173294642922, 'colsample_bytree': 0.5016540350360709, 'min_child_weight': 7, 'gamma': 0.17166715840074107}. Best is trial 54 with value: -0.20413640141487122.
# [I 2026-01-12 02:43:58,066] Trial 60 finished with value: -0.21217899521191916 and parameters: {'max_depth': 10, 'learning_rate': 0.02105271596518279, 'n_estimators': 565, 'subsample': 0.9300942413443478, 'colsample_bytree': 0.5372051563703163, 'min_child_weight': 7, 'gamma': 1.0405302177540638}. Best is trial 54 with value: -0.20413640141487122.
# [I 2026-01-12 02:44:08,924] Trial 61 finished with value: -0.20472397406895956 and parameters: {'max_depth': 10, 'learning_rate': 0.01584789724795475, 'n_estimators': 696, 'subsample': 0.8995788048394814, 'colsample_bytree': 0.5050741428772891, 'min_child_weight': 6, 'gamma': 0.1962976385089952}. Best is trial 54 with value: -0.20413640141487122.
# [I 2026-01-12 02:44:14,821] Trial 62 finished with value: -0.20905940731366476 and parameters: {'max_depth': 10, 'learning_rate': 0.01568633291451995, 'n_estimators': 652, 'subsample': 0.8833422242159846, 'colsample_bytree': 0.5011230635161115, 'min_child_weight': 6, 'gamma': 0.5667291636420009}. Best is trial 54 with value: -0.20413640141487122.
# [I 2026-01-12 02:44:24,121] Trial 63 finished with value: -0.2044314444065094 and parameters: {'max_depth': 10, 'learning_rate': 0.02015469244188764, 'n_estimators': 615, 'subsample': 0.9417629046230751, 'colsample_bytree': 0.521758097276352, 'min_child_weight': 7, 'gamma': 0.16042736632345905}. Best is trial 54 with value: -0.20413640141487122.
# [I 2026-01-12 02:44:35,809] Trial 64 finished with value: -0.21754942337671915 and parameters: {'max_depth': 10, 'learning_rate': 0.020727007667697524, 'n_estimators': 487, 'subsample': 0.9558819374719053, 'colsample_bytree': 0.9970969771547256, 'min_child_weight': 8, 'gamma': 0.13240478565294825}. Best is trial 54 with value: -0.20413640141487122.
# [I 2026-01-12 02:44:38,572] Trial 65 finished with value: -0.23276257514953613 and parameters: {'max_depth': 10, 'learning_rate': 0.015224197315272098, 'n_estimators': 605, 'subsample': 0.8954240543646339, 'colsample_bytree': 0.5245271237172131, 'min_child_weight': 7, 'gamma': 3.9268617845166816}. Best is trial 54 with value: -0.20413640141487122.
# [I 2026-01-12 02:44:41,447] Trial 66 finished with value: -0.21057009200255075 and parameters: {'max_depth': 10, 'learning_rate': 0.035344444818428626, 'n_estimators': 444, 'subsample': 0.9578641530650159, 'colsample_bytree': 0.539877641134403, 'min_child_weight': 5, 'gamma': 0.5911897103535935}. Best is trial 54 with value: -0.20413640141487122.
# [I 2026-01-12 02:44:47,425] Trial 67 finished with value: -0.2026261587937673 and parameters: {'max_depth': 9, 'learning_rate': 0.039849353495535644, 'n_estimators': 563, 'subsample': 0.8445937713102851, 'colsample_bytree': 0.5584961516330215, 'min_child_weight': 7, 'gamma': 0.1689651605926895}. Best is trial 67 with value: -0.2026261587937673.
# [I 2026-01-12 02:44:49,598] Trial 68 finished with value: -0.21206270158290863 and parameters: {'max_depth': 9, 'learning_rate': 0.042767708862586074, 'n_estimators': 567, 'subsample': 0.829902402641879, 'colsample_bytree': 0.5567038123847653, 'min_child_weight': 8, 'gamma': 0.7960456008866558}. Best is trial 67 with value: -0.2026261587937673.
# [I 2026-01-12 02:44:52,888] Trial 69 finished with value: -0.20719956358273825 and parameters: {'max_depth': 9, 'learning_rate': 0.03132907763844493, 'n_estimators': 525, 'subsample': 0.8407460884329445, 'colsample_bytree': 0.5227978282661266, 'min_child_weight': 7, 'gamma': 0.4589562781622667}. Best is trial 67 with value: -0.2026261587937673.
# [I 2026-01-12 02:44:59,241] Trial 70 finished with value: -0.20417127013206482 and parameters: {'max_depth': 9, 'learning_rate': 0.040141750087617285, 'n_estimators': 613, 'subsample': 0.793151106405175, 'colsample_bytree': 0.5773439327017634, 'min_child_weight': 7, 'gamma': 0.15860046718731727}. Best is trial 67 with value: -0.2026261587937673.
# [I 2026-01-12 02:45:04,621] Trial 71 finished with value: -0.20286042988300323 and parameters: {'max_depth': 9, 'learning_rate': 0.03737805956894662, 'n_estimators': 602, 'subsample': 0.7825069120613377, 'colsample_bytree': 0.572566856545601, 'min_child_weight': 7, 'gamma': 0.13414568649340736}. Best is trial 67 with value: -0.2026261587937673.
# [I 2026-01-12 02:45:11,437] Trial 72 finished with value: -0.20297429462273917 and parameters: {'max_depth': 8, 'learning_rate': 0.03907583757739788, 'n_estimators': 605, 'subsample': 0.7950527449144412, 'colsample_bytree': 0.584702063259176, 'min_child_weight': 7, 'gamma': 0.12078306986094123}. Best is trial 67 with value: -0.2026261587937673.
# [I 2026-01-12 02:45:17,701] Trial 73 finished with value: -0.20349891980489096 and parameters: {'max_depth': 8, 'learning_rate': 0.04609122167225861, 'n_estimators': 616, 'subsample': 0.7877799455755228, 'colsample_bytree': 0.5810679303522944, 'min_child_weight': 7, 'gamma': 0.0074243738508886215}. Best is trial 67 with value: -0.2026261587937673.
# [I 2026-01-12 02:45:25,899] Trial 74 finished with value: -0.20263157288233438 and parameters: {'max_depth': 8, 'learning_rate': 0.04580084670130141, 'n_estimators': 612, 'subsample': 0.7872340081428688, 'colsample_bytree': 0.5860781363928211, 'min_child_weight': 7, 'gamma': 0.001942348958774348}. Best is trial 67 with value: -0.2026261587937673.
# [I 2026-01-12 02:45:32,111] Trial 75 finished with value: -0.20225981871287027 and parameters: {'max_depth': 8, 'learning_rate': 0.04639795974059017, 'n_estimators': 613, 'subsample': 0.7852738664355213, 'colsample_bytree': 0.5897881257013269, 'min_child_weight': 7, 'gamma': 0.031246230506440514}. Best is trial 75 with value: -0.20225981871287027.
# [I 2026-01-12 02:45:40,509] Trial 76 finished with value: -0.2023814618587494 and parameters: {'max_depth': 8, 'learning_rate': 0.04590529878652231, 'n_estimators': 659, 'subsample': 0.7906029096066509, 'colsample_bytree': 0.5897613764645572, 'min_child_weight': 8, 'gamma': 0.02020400119328726}. Best is trial 75 with value: -0.20225981871287027.
# [I 2026-01-12 02:45:49,025] Trial 77 finished with value: -0.20218953490257263 and parameters: {'max_depth': 8, 'learning_rate': 0.047198116421056216, 'n_estimators': 665, 'subsample': 0.79127384239717, 'colsample_bytree': 0.5895059310965275, 'min_child_weight': 8, 'gamma': 0.015563110042979375}. Best is trial 77 with value: -0.20218953490257263.
# [I 2026-01-12 02:45:50,671] Trial 78 finished with value: -0.22804525991280875 and parameters: {'max_depth': 8, 'learning_rate': 0.046088297484762376, 'n_estimators': 653, 'subsample': 0.7562486201006062, 'colsample_bytree': 0.5890406223145898, 'min_child_weight': 8, 'gamma': 2.4098201594036657}. Best is trial 77 with value: -0.20218953490257263.
# [I 2026-01-12 02:45:56,420] Trial 79 finished with value: -0.20177574952443442 and parameters: {'max_depth': 8, 'learning_rate': 0.04845438898680296, 'n_estimators': 549, 'subsample': 0.8084837801913655, 'colsample_bytree': 0.6099418123372427, 'min_child_weight': 9, 'gamma': 0.005632911830062788}. Best is trial 79 with value: -0.20177574952443442.
# [I 2026-01-12 02:45:58,506] Trial 80 finished with value: -0.2093812276919683 and parameters: {'max_depth': 8, 'learning_rate': 0.05263055183786637, 'n_estimators': 497, 'subsample': 0.8104969925273376, 'colsample_bytree': 0.6076414215211501, 'min_child_weight': 9, 'gamma': 0.5205996104344831}. Best is trial 79 with value: -0.20177574952443442.
# [I 2026-01-12 02:46:06,334] Trial 81 finished with value: -0.20131882528463999 and parameters: {'max_depth': 8, 'learning_rate': 0.046579199678508994, 'n_estimators': 555, 'subsample': 0.8467737637429552, 'colsample_bytree': 0.6285841187617363, 'min_child_weight': 9, 'gamma': 0.013498934149687617}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:46:13,852] Trial 82 finished with value: -0.20183855791886648 and parameters: {'max_depth': 8, 'learning_rate': 0.04841474478953476, 'n_estimators': 557, 'subsample': 0.8591916901479375, 'colsample_bytree': 0.6341528024324752, 'min_child_weight': 9, 'gamma': 0.012361901767169163}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:46:18,660] Trial 83 finished with value: -0.20375979443391165 and parameters: {'max_depth': 7, 'learning_rate': 0.04992890633018005, 'n_estimators': 560, 'subsample': 0.848008632706408, 'colsample_bytree': 0.6437822509478668, 'min_child_weight': 9, 'gamma': 0.040834441097204924}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:46:21,349] Trial 84 finished with value: -0.20690797766049704 and parameters: {'max_depth': 8, 'learning_rate': 0.04792851212170487, 'n_estimators': 670, 'subsample': 0.8639458444272976, 'colsample_bytree': 0.6694406673130316, 'min_child_weight': 10, 'gamma': 0.3856583334257328}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:46:23,978] Trial 85 finished with value: -0.2081991583108902 and parameters: {'max_depth': 8, 'learning_rate': 0.04402244121884885, 'n_estimators': 639, 'subsample': 0.8103927286961897, 'colsample_bytree': 0.6258947205717432, 'min_child_weight': 9, 'gamma': 0.46819910762910066}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:46:30,988] Trial 86 finished with value: -0.20286968350410461 and parameters: {'max_depth': 8, 'learning_rate': 0.05256141755270792, 'n_estimators': 457, 'subsample': 0.7732646170419788, 'colsample_bytree': 0.6126558684677909, 'min_child_weight': 8, 'gamma': 0.004629235026867294}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:46:33,478] Trial 87 finished with value: -0.207915132244428 and parameters: {'max_depth': 7, 'learning_rate': 0.05513360985033022, 'n_estimators': 548, 'subsample': 0.8265350289617239, 'colsample_bytree': 0.6346861381592939, 'min_child_weight': 9, 'gamma': 0.3173153177449104}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:46:35,195] Trial 88 finished with value: -0.21573386589686075 and parameters: {'max_depth': 7, 'learning_rate': 0.04763113601805686, 'n_estimators': 405, 'subsample': 0.8526190245172733, 'colsample_bytree': 0.6549250449585794, 'min_child_weight': 8, 'gamma': 0.6660364853919302}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:46:39,710] Trial 89 finished with value: -0.20785305897394815 and parameters: {'max_depth': 8, 'learning_rate': 0.03573406517940758, 'n_estimators': 514, 'subsample': 0.8161480150448489, 'colsample_bytree': 0.5967566198005981, 'min_child_weight': 10, 'gamma': 0.4347451452437487}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:46:44,578] Trial 90 finished with value: -0.20255271593729654 and parameters: {'max_depth': 8, 'learning_rate': 0.044827243463204124, 'n_estimators': 583, 'subsample': 0.7424904732493488, 'colsample_bytree': 0.5666598854105668, 'min_child_weight': 8, 'gamma': 0.10304786257224668}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:46:49,199] Trial 91 finished with value: -0.20358002185821533 and parameters: {'max_depth': 8, 'learning_rate': 0.043619087969906246, 'n_estimators': 550, 'subsample': 0.7740667279906398, 'colsample_bytree': 0.5677968429828413, 'min_child_weight': 8, 'gamma': 0.09983006441934772}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:46:56,150] Trial 92 finished with value: -0.2020800511042277 and parameters: {'max_depth': 8, 'learning_rate': 0.05128614287768298, 'n_estimators': 582, 'subsample': 0.7519516934709508, 'colsample_bytree': 0.6224563278068168, 'min_child_weight': 9, 'gamma': 0.08975623462753883}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:46:59,178] Trial 93 finished with value: -0.2062129924694697 and parameters: {'max_depth': 7, 'learning_rate': 0.05089603185126043, 'n_estimators': 587, 'subsample': 0.7402058268063394, 'colsample_bytree': 0.6190965390205572, 'min_child_weight': 9, 'gamma': 0.2769454799401286}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:47:06,191] Trial 94 finished with value: -0.2035970836877823 and parameters: {'max_depth': 8, 'learning_rate': 0.057101714037899494, 'n_estimators': 476, 'subsample': 0.7495754477940244, 'colsample_bytree': 0.6445141534330476, 'min_child_weight': 9, 'gamma': 0.0008317239548170652}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:47:08,853] Trial 95 finished with value: -0.20612172285715738 and parameters: {'max_depth': 8, 'learning_rate': 0.04552468493218607, 'n_estimators': 509, 'subsample': 0.8392619814155904, 'colsample_bytree': 0.6864102202419532, 'min_child_weight': 8, 'gamma': 0.3540518174773022}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:47:10,438] Trial 96 finished with value: -0.23279087245464325 and parameters: {'max_depth': 8, 'learning_rate': 0.04168658257245169, 'n_estimators': 670, 'subsample': 0.7995899861173653, 'colsample_bytree': 0.5937697593934065, 'min_child_weight': 9, 'gamma': 3.2381492540675896}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:47:14,543] Trial 97 finished with value: -0.20334438979625702 and parameters: {'max_depth': 7, 'learning_rate': 0.04839446954255329, 'n_estimators': 582, 'subsample': 0.872010847129648, 'colsample_bytree': 0.607697889614173, 'min_child_weight': 8, 'gamma': 0.10072187477959534}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:47:18,585] Trial 98 finished with value: -0.21017670631408691 and parameters: {'max_depth': 8, 'learning_rate': 0.06010315453100256, 'n_estimators': 631, 'subsample': 0.7576185750260125, 'colsample_bytree': 0.6295937656059756, 'min_child_weight': 10, 'gamma': 0.5566843808325425}. Best is trial 81 with value: -0.20131882528463999.
# [I 2026-01-12 02:47:21,468] Trial 99 finished with value: -0.20538122951984406 and parameters: {'max_depth': 8, 'learning_rate': 0.054157359959451104, 'n_estimators': 539, 'subsample': 0.8192236871186087, 'colsample_bytree': 0.6671950212516853, 'min_child_weight': 9, 'gamma': 0.26839019969315886}. Best is trial 81 with value: -0.20131882528463999.

# %% [markdown]
# ### Training using best params

# %%
# ----------------------------------------------
# Model training using best parameters
# ----------------------------------------------

# Best parameters
best_params = study.best_params

# Training
model = xgb.XGBRegressor(**best_params)
model.fit(train_valid_data[feature_names], train_valid_data[target_name])
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.6285841187617363, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.013498934149687617, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.046579199678508994,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=9, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=555, n_jobs=None,
#              num_parallel_tree=None, ...)

# %% [markdown]
# ### Evaluation

# %%
# ----------------------------------------------
# Categoty encoding of test dataset
# ----------------------------------------------
for col, enc in categorical_encoders.items():
    test_data[col+'_encoded'] = enc.transform(test_data[col])

# %%
# ----------------------------------------------
# Model evaluation by test data
# ----------------------------------------------

# Prediction (train)
y_pred_train = model.predict(train_valid_data[feature_names])

# Prediction (Test)
y_pred_test = model.predict(test_data[feature_names])

# Plot
plt.scatter(y_pred_train, train_valid_data[target_name].values.ravel(), s=10, color='k', alpha=0.3)
plt.scatter(y_pred_test, test_data[target_name].values.ravel(), s=10, color='r', alpha=0.3)
plt.plot([y_pred_train.min(), y_pred_train.max()], [y_pred_train.min(), y_pred_train.max()], color='b')
plt.xlabel('Prediction')
plt.ylabel('Actual')
plt.show()

# Metrics
RMSE_train = mean_squared_error(y_true = train_valid_data[target_name].values.ravel(), y_pred = y_pred_train)
RMSE_test = mean_squared_error(y_true = test_data[target_name].values.ravel(), y_pred = y_pred_test)
print(f'Train RMSE: {RMSE_train:.5f}')
print(f'Test RMSE: {RMSE_test:.5f}')
# Out:
# Train RMSE: 0.04151
# Test RMSE: 0.19412

# %% [markdown]
# ### SHAP explanation

# %%
# ----------------------------------------------
# Shap value calculation
# ----------------------------------------------
explainer = shap.TreeExplainer(model, data=train_valid_data[feature_names])
shape_values = explainer.shap_values(train_valid_data[feature_names])
# Out:
# 100%|===================| 16503/16512 [21:03<00:00]

# %%
# ----------------------------------------------
# Plot 1
# ----------------------------------------------
shap.summary_plot(
    shap_values=shape_values,
    features=train_valid_data[feature_names],
    feature_names=feature_names
)

# %%
# ----------------------------------------------
# Plot 2
# ----------------------------------------------
shap.summary_plot(
    shap_values=shape_values,
    features=train_valid_data[feature_names],
    feature_names=feature_names,
    plot_type = 'bar'
)

# %%
# ----------------------------------------------
# Plot 3
# ----------------------------------------------

fig, ax = plt.subplots(2, 5, figsize = (30, 7))
ax = ax.ravel()
for i, feature_name in enumerate(feature_names):
    ax[i].scatter(train_valid_data[feature_names].values[:,i], shape_values[:,i], s = 10)
    ax[i].set_xlabel(feature_name, fontsize = 9)
    ax[i].set_ylabel('SHAP value', fontsize = 9)
