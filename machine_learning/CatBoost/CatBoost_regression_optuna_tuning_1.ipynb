# %% [markdown]
# # CatBoost Regression sample
# ### Hold out simple optune tuning

# %% [markdown]
# ### Import libraries

# %%
# !pip install shap
# !pip install optuna
# !pip install catboost
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.12/dist-packages (0.50.0)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from shap) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from shap) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.12/dist-packages (from shap) (25.0)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from shap) (4.15.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.45)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Requirement already satisfied: catboost in /usr/local/lib/python3.12/dist-packages (1.2.8)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.2.5)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (9.1.2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy.stats import loguniform
from tqdm import tqdm

from catboost import CatBoostRegressor
from catboost import Pool
import optuna
import shap

# %% [markdown]
# ### Dataset

# %%
# ----------------------------------------------
# Create sample dataset
# ----------------------------------------------

# Dataset
housing = fetch_california_housing()
housing_data = pd.DataFrame(data = housing.data, columns = housing.feature_names)
housing_data['target'] = housing.target
housing_data.reset_index(inplace = True, drop = True)

# Functions
def make_correlation_category(
        x_grid: list,
        y_grid: list,
        x_feature_name: str,
        y_feature_name: str,
        datset: pd.core.frame.DataFrame,
        catefory_names = list('ABCDEFGHIJKLMNOPQLSTUVWXYZ')
):
    i = 0
    index_list = []
    category_list = []
    for y1, y2 in zip(y_grid[:-1], y_grid[1:]):
        for x1, x2 in zip(x_grid[:-1], x_grid[1:]):
            temp_data = datset[(x1<=datset[x_feature_name]) & (datset[x_feature_name]<x2) & (y1<=datset[y_feature_name]) & (datset[y_feature_name]<y2)].copy()
            if temp_data.shape[0] > 0:
                index_list += temp_data.index.tolist()
                category_list += [catefory_names[i] for k in range(temp_data.shape[0])]
                i += 1
    return np.array(category_list)[np.argsort(np.array(index_list))]

# Make categorical features 1
housing_data['Area_category'] = make_correlation_category(
    x_grid = [32, 34, 36, 38, 40, 44],
    y_grid = [-126, -122, -120, -118, -116, -114],
    x_feature_name = 'Latitude',
    y_feature_name = 'Longitude',
    datset = housing_data,
)

# Make categorical features 2
housing_data['Room_num_category'] = make_correlation_category(
    x_grid = [0, 5, 10, 40],
    y_grid = [0, 20, 40, 170],
    x_feature_name = 'AveBedrms',
    y_feature_name = 'AveRooms',
    datset = housing_data,
)

# %%
housing_data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  target Area_category Room_num_category
# 0        -122.23   4.526             A                 A
# 1        -122.22   3.585             A                 A
# 2        -122.24   3.521             A                 A
# 3        -122.25   3.413             A                 A
# 4        -122.25   3.422             A                 A
# ...          ...     ...           ...               ...
# 20635    -121.09   0.781             F                 A
# 20636    -121.21   0.771             F                 A
# 20637    -121.22   0.923             F                 A
# 20638    -121.32   0.847             F                 A
# 20639    -121.24   0.894             F                 A
#
# [20640 rows x 11 columns]

# %% [markdown]
# ### Train-test split

# %%
train_valid_data, test_data = train_test_split(housing_data, test_size=0.2, shuffle=True)
print(f'Train & validation data shape: {train_valid_data.shape}')
print(f'Test data shape: {test_data.shape}')
# Out:
# Train & validation data shape: (16512, 11)
# Test data shape: (4128, 11)

# %% [markdown]
# ### Category encoding

# %%
# ----------------------------------------------
# Categorical encoding
# ----------------------------------------------

categorical_featues = ['Area_category', 'Room_num_category']
categorical_encoders = {}
for col in categorical_featues:
    enc = LabelEncoder()
    enc.fit(train_valid_data[col].unique())
    train_valid_data[col+'_encoded'] = enc.transform(train_valid_data[col])
    categorical_encoders[col] = enc

# %% [markdown]
# ### Tuning hyper-parameters

# %%
# ----------------------------------------------
# Hyper parameter tuning by optuna
# ----------------------------------------------

# Feature names
feature_names = ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude', 'Area_category_encoded', 'Room_num_category_encoded']
target_name = ['target']

# Trial function
def objective(trial):

    # Train-validation split
    X_train, X_valid, y_train, y_valid = train_test_split(train_valid_data[feature_names], train_valid_data[target_name], shuffle = True, test_size = 0.2)

    # Parameters
    tuning_parameters = {
        'learning_rate' : trial.suggest_float('learning_rate', 0.001, 0.3, log=True),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.01, 0.1),
        'max_depth': trial.suggest_int('max_depth', 5, 15),
        'boosting_type': trial.suggest_categorical('boosting_type', ['Ordered', 'Plain']),
        'bootstrap_type': trial.suggest_categorical('bootstrap_type', ['Bayesian', 'Bernoulli', 'MVS']),
        'iterations' : trial.suggest_int('iterations', 50, 300),
    }

    if tuning_parameters["bootstrap_type"] == "Bayesian":
        tuning_parameters["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)

    elif tuning_parameters["bootstrap_type"] == "Bernoulli":
        tuning_parameters["subsample"] = trial.suggest_float("subsample", 0.1, 1)

    # Training
    model = CatBoostRegressor(**tuning_parameters)
    model.fit(X_train, y_train, verbose = 0)

    # Validation
    y_pred = model.predict(X_valid)
    RMSE = mean_squared_error(y_true = y_valid.values.ravel(), y_pred = y_pred)
    return RMSE

# Tuning
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
# [I 2026-01-12 00:30:23,914] A new study created in memory with name: no-name-85d7c59f-6313-4888-a6ea-cb462b0f62c8
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-01-12 00:30:24,491] Trial 0 finished with value: 1.1567985513637928 and parameters: {'learning_rate': 0.013813071405848976, 'colsample_bylevel': 0.0197894920877376, 'max_depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 264, 'subsample': 0.13750425725378856}. Best is trial 0 with value: 1.1567985513637928.
# [I 2026-01-12 00:30:26,341] Trial 1 finished with value: 0.28120964094212764 and parameters: {'learning_rate': 0.12857163160702184, 'colsample_bylevel': 0.09940540465842593, 'max_depth': 13, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 299, 'subsample': 0.6462229757122663}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:26,732] Trial 2 finished with value: 1.2733347548333818 and parameters: {'learning_rate': 0.004949456773069023, 'colsample_bylevel': 0.02752839538007125, 'max_depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'iterations': 156, 'bagging_temperature': 5.395700456475474}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:27,600] Trial 3 finished with value: 1.0612561747840175 and parameters: {'learning_rate': 0.005337867012026358, 'colsample_bylevel': 0.09623097388469734, 'max_depth': 15, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'iterations': 222, 'bagging_temperature': 3.257737479118256}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:27,972] Trial 4 finished with value: 0.9783433728734551 and parameters: {'learning_rate': 0.007439371938644125, 'colsample_bylevel': 0.07974061082954437, 'max_depth': 15, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'iterations': 254}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:28,103] Trial 5 finished with value: 1.2690897404681765 and parameters: {'learning_rate': 0.10664525470127834, 'colsample_bylevel': 0.020292764287707852, 'max_depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'iterations': 68, 'bagging_temperature': 6.8952403911294}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:28,430] Trial 6 finished with value: 1.3259579751226127 and parameters: {'learning_rate': 0.0024706197411776213, 'colsample_bylevel': 0.02510581881484997, 'max_depth': 15, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'iterations': 160}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:28,644] Trial 7 finished with value: 1.2952414892449347 and parameters: {'learning_rate': 0.0035477271423038515, 'colsample_bylevel': 0.05343566102467996, 'max_depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 154, 'subsample': 0.47367089595831224}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:29,131] Trial 8 finished with value: 0.7890057264605728 and parameters: {'learning_rate': 0.20807633325498243, 'colsample_bylevel': 0.011309811187888423, 'max_depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 206, 'subsample': 0.15764480472853656}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:29,728] Trial 9 finished with value: 1.1294866750648138 and parameters: {'learning_rate': 0.006283129485642516, 'colsample_bylevel': 0.0755370461931243, 'max_depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'iterations': 207, 'bagging_temperature': 2.7540977210124176}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:30,414] Trial 10 finished with value: 0.5952854630803198 and parameters: {'learning_rate': 0.055223447876963365, 'colsample_bylevel': 0.048669703601823426, 'max_depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 296, 'subsample': 0.9708169443899726}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:31,107] Trial 11 finished with value: 0.6034101401748707 and parameters: {'learning_rate': 0.059282056416899084, 'colsample_bylevel': 0.04523430918328524, 'max_depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 300, 'subsample': 0.9888242435040409}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:31,841] Trial 12 finished with value: 0.5293506850773628 and parameters: {'learning_rate': 0.04231287017746695, 'colsample_bylevel': 0.06908679319293304, 'max_depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 292, 'subsample': 0.9431139383996949}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:32,818] Trial 13 finished with value: 0.46160712900221407 and parameters: {'learning_rate': 0.03208609872134003, 'colsample_bylevel': 0.09784908896426045, 'max_depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 259, 'subsample': 0.6865587790382212}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:33,521] Trial 14 finished with value: 0.5645894356827166 and parameters: {'learning_rate': 0.022791267600473352, 'colsample_bylevel': 0.0929097230500268, 'max_depth': 13, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 250, 'subsample': 0.6378252281312443}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:34,561] Trial 15 finished with value: 0.33426246837475904 and parameters: {'learning_rate': 0.28808378252582434, 'colsample_bylevel': 0.0862626984275528, 'max_depth': 13, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 104, 'subsample': 0.6500936935506811}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:35,412] Trial 16 finished with value: 0.3248853244147238 and parameters: {'learning_rate': 0.27359447908500895, 'colsample_bylevel': 0.08499178119473126, 'max_depth': 13, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'iterations': 100}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:36,205] Trial 17 finished with value: 1.3118653548603785 and parameters: {'learning_rate': 0.0011672758952907276, 'colsample_bylevel': 0.06576483386963913, 'max_depth': 14, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'iterations': 107}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:36,482] Trial 18 finished with value: 0.426344240153864 and parameters: {'learning_rate': 0.1218677588556689, 'colsample_bylevel': 0.08227272565048435, 'max_depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'iterations': 115}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:36,678] Trial 19 finished with value: 0.6378824884467427 and parameters: {'learning_rate': 0.15992725738406813, 'colsample_bylevel': 0.062085263200102464, 'max_depth': 14, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'iterations': 50}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:37,318] Trial 20 finished with value: 0.3768351312476392 and parameters: {'learning_rate': 0.08772924554039134, 'colsample_bylevel': 0.08852708631373021, 'max_depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'iterations': 184}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:37,979] Trial 21 finished with value: 0.3281423734877482 and parameters: {'learning_rate': 0.2903309393076537, 'colsample_bylevel': 0.0870796767198685, 'max_depth': 13, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 111, 'subsample': 0.43446868899327007}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:38,273] Trial 22 finished with value: 0.3157352393105821 and parameters: {'learning_rate': 0.2830451100958022, 'colsample_bylevel': 0.09943372167613185, 'max_depth': 13, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 75, 'subsample': 0.43801601308279625}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:38,598] Trial 23 finished with value: 0.38884191252417644 and parameters: {'learning_rate': 0.17932018701057534, 'colsample_bylevel': 0.09887951003857465, 'max_depth': 14, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'iterations': 66}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:38,892] Trial 24 finished with value: 0.6263002576916873 and parameters: {'learning_rate': 0.07745980433019505, 'colsample_bylevel': 0.07338102114093822, 'max_depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 86, 'subsample': 0.36585747360754217}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:39,398] Trial 25 finished with value: 0.33794942973144115 and parameters: {'learning_rate': 0.1506542329539363, 'colsample_bylevel': 0.09161846053152722, 'max_depth': 13, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'iterations': 132}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:39,707] Trial 26 finished with value: 0.29423425738420256 and parameters: {'learning_rate': 0.28625891497905204, 'colsample_bylevel': 0.09988587137721218, 'max_depth': 14, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 85, 'subsample': 0.3493354965564226}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:39,893] Trial 27 finished with value: 0.8890307995535894 and parameters: {'learning_rate': 0.014282620543181622, 'colsample_bylevel': 0.09823629249178945, 'max_depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 133, 'subsample': 0.2963979030504201}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:40,014] Trial 28 finished with value: 0.6065080415520444 and parameters: {'learning_rate': 0.18891317116364864, 'colsample_bylevel': 0.03790777485181726, 'max_depth': 14, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 78, 'subsample': 0.7908436835947392}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:40,290] Trial 29 finished with value: 0.34852580126266475 and parameters: {'learning_rate': 0.11176428646270901, 'colsample_bylevel': 0.0777813698201799, 'max_depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 228, 'subsample': 0.2986476860778837}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:40,418] Trial 30 finished with value: 0.9895589989626894 and parameters: {'learning_rate': 0.02212840851036565, 'colsample_bylevel': 0.09292451507395189, 'max_depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 55, 'subsample': 0.48828591569247554}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:40,790] Trial 31 finished with value: 0.35604296124072426 and parameters: {'learning_rate': 0.28614853361916154, 'colsample_bylevel': 0.084350975364028, 'max_depth': 14, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 94, 'subsample': 0.5660353498921291}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:41,089] Trial 32 finished with value: 0.3928686408505297 and parameters: {'learning_rate': 0.22205545119505263, 'colsample_bylevel': 0.0919020812247771, 'max_depth': 13, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'iterations': 133, 'bagging_temperature': 9.606496338200017}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:41,412] Trial 33 finished with value: 0.3925251513250099 and parameters: {'learning_rate': 0.14149335680565253, 'colsample_bylevel': 0.099712515720658, 'max_depth': 15, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 77, 'subsample': 0.8044823349166934}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:41,798] Trial 34 finished with value: 0.3553778197073104 and parameters: {'learning_rate': 0.22702076342500685, 'colsample_bylevel': 0.0927792442234561, 'max_depth': 15, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'iterations': 95, 'bagging_temperature': 0.2884381120747461}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:42,222] Trial 35 finished with value: 0.34380372946655324 and parameters: {'learning_rate': 0.08028279861773288, 'colsample_bylevel': 0.08205117275476562, 'max_depth': 12, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'iterations': 278}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:42,866] Trial 36 finished with value: 0.2846285095926744 and parameters: {'learning_rate': 0.2952689969722962, 'colsample_bylevel': 0.09982800378382768, 'max_depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 180, 'subsample': 0.2655236438695993}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:43,180] Trial 37 finished with value: 0.32001272400946207 and parameters: {'learning_rate': 0.10885921463134912, 'colsample_bylevel': 0.09519717965182539, 'max_depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 240, 'subsample': 0.24830577532372727}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:43,675] Trial 38 finished with value: 1.0088488277859844 and parameters: {'learning_rate': 0.009338347574106457, 'colsample_bylevel': 0.08900242990364486, 'max_depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 177, 'subsample': 0.3590229274974928}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:43,925] Trial 39 finished with value: 0.32747570890297373 and parameters: {'learning_rate': 0.1681326620763656, 'colsample_bylevel': 0.0995947567491783, 'max_depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 200, 'subsample': 0.2260709968586852}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:44,349] Trial 40 finished with value: 0.9182420113150622 and parameters: {'learning_rate': 0.05520042379150441, 'colsample_bylevel': 0.0320599575335937, 'max_depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'iterations': 154, 'bagging_temperature': 9.744339018427867}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:44,623] Trial 41 finished with value: 0.3369528246951478 and parameters: {'learning_rate': 0.11417525755426032, 'colsample_bylevel': 0.09414663151613746, 'max_depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 241, 'subsample': 0.2678207060927908}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:44,972] Trial 42 finished with value: 0.2896345213830387 and parameters: {'learning_rate': 0.21537979093817333, 'colsample_bylevel': 0.09451038490384019, 'max_depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 276, 'subsample': 0.38952387637776353}. Best is trial 1 with value: 0.28120964094212764.
# [I 2026-01-12 00:30:45,329] Trial 43 finished with value: 0.27848657590106385 and parameters: {'learning_rate': 0.21847599520148778, 'colsample_bylevel': 0.08934671288830127, 'max_depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 278, 'subsample': 0.37755416838267153}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:45,616] Trial 44 finished with value: 0.28863232507644543 and parameters: {'learning_rate': 0.2154456894657983, 'colsample_bylevel': 0.08001155310632523, 'max_depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 274, 'subsample': 0.39505514884357207}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:45,910] Trial 45 finished with value: 0.29014279751423366 and parameters: {'learning_rate': 0.21048440035980598, 'colsample_bylevel': 0.07978682132793238, 'max_depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 271, 'subsample': 0.5404966029176247}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:46,187] Trial 46 finished with value: 0.3726450732063064 and parameters: {'learning_rate': 0.138860648252608, 'colsample_bylevel': 0.05860109778331536, 'max_depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 281, 'subsample': 0.3670646273125898}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:46,566] Trial 47 finished with value: 0.39424760948717047 and parameters: {'learning_rate': 0.07136624607671527, 'colsample_bylevel': 0.0734942656830454, 'max_depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 287, 'subsample': 0.200632652034682}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:47,370] Trial 48 finished with value: 0.42476187122277714 and parameters: {'learning_rate': 0.040869590697109354, 'colsample_bylevel': 0.08907365036489022, 'max_depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 267, 'subsample': 0.11647450371992418}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:48,067] Trial 49 finished with value: 0.3124429258033797 and parameters: {'learning_rate': 0.21694563793811913, 'colsample_bylevel': 0.07091252859819677, 'max_depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 300, 'subsample': 0.41488281007237543}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:48,629] Trial 50 finished with value: 0.8975175505444687 and parameters: {'learning_rate': 0.09874170804552189, 'colsample_bylevel': 0.012491698676595504, 'max_depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'iterations': 250, 'bagging_temperature': 0.4907798267433945}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:49,174] Trial 51 finished with value: 0.29170646278074186 and parameters: {'learning_rate': 0.2031911124800069, 'colsample_bylevel': 0.07793224736257817, 'max_depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 270, 'subsample': 0.5403181758897371}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:49,510] Trial 52 finished with value: 0.2850508850835606 and parameters: {'learning_rate': 0.22472452175102603, 'colsample_bylevel': 0.08264925926757885, 'max_depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 274, 'subsample': 0.5360607129649997}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:49,829] Trial 53 finished with value: 0.2855118854159804 and parameters: {'learning_rate': 0.14412284824297364, 'colsample_bylevel': 0.08328293264556362, 'max_depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 288, 'subsample': 0.49363494788278217}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:50,187] Trial 54 finished with value: 0.3192215377495937 and parameters: {'learning_rate': 0.14377914019890173, 'colsample_bylevel': 0.08141752670401425, 'max_depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 287, 'subsample': 0.6074141872197756}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:50,448] Trial 55 finished with value: 1.1216428626973407 and parameters: {'learning_rate': 0.004308287036214576, 'colsample_bylevel': 0.0670978109561291, 'max_depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 260, 'subsample': 0.48026583736830536}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:50,715] Trial 56 finished with value: 0.31067614804407284 and parameters: {'learning_rate': 0.170804649576104, 'colsample_bylevel': 0.08385807351873739, 'max_depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 219, 'subsample': 0.7148507396830328}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:51,097] Trial 57 finished with value: 1.1869817566614753 and parameters: {'learning_rate': 0.002285615834962616, 'colsample_bylevel': 0.08791543659867306, 'max_depth': 12, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 292, 'subsample': 0.49935616938918276}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:51,386] Trial 58 finished with value: 0.3200080242315886 and parameters: {'learning_rate': 0.13335616874559156, 'colsample_bylevel': 0.0760179712893624, 'max_depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 242, 'subsample': 0.5765282790281228}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:51,736] Trial 59 finished with value: 0.36214977787711977 and parameters: {'learning_rate': 0.06645299827165019, 'colsample_bylevel': 0.09001223988233668, 'max_depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 253, 'subsample': 0.5100236664241231}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:52,663] Trial 60 finished with value: 0.34484975151160485 and parameters: {'learning_rate': 0.08755737081654406, 'colsample_bylevel': 0.08517740292583781, 'max_depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 285, 'subsample': 0.17515751697300821}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:52,991] Trial 61 finished with value: 0.29102352591247915 and parameters: {'learning_rate': 0.24318138921204885, 'colsample_bylevel': 0.09507123784931511, 'max_depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 277, 'subsample': 0.40987291612507315}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:53,314] Trial 62 finished with value: 0.2867593628234833 and parameters: {'learning_rate': 0.18296365844790646, 'colsample_bylevel': 0.09570181560608662, 'max_depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 263, 'subsample': 0.31301980621498626}. Best is trial 43 with value: 0.27848657590106385.
# [I 2026-01-12 00:30:53,698] Trial 63 finished with value: 0.2525475514465152 and parameters: {'learning_rate': 0.16986438573813004, 'colsample_bylevel': 0.09662938852897267, 'max_depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 299, 'subsample': 0.4608598029160743}. Best is trial 63 with value: 0.2525475514465152.
# [I 2026-01-12 00:30:54,064] Trial 64 finished with value: 0.29838589457300924 and parameters: {'learning_rate': 0.15962667542564368, 'colsample_bylevel': 0.09620375613554684, 'max_depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 262, 'subsample': 0.3317403749923038}. Best is trial 63 with value: 0.2525475514465152.
# [I 2026-01-12 00:30:54,572] Trial 65 finished with value: 0.29254966194815935 and parameters: {'learning_rate': 0.09720543446164792, 'colsample_bylevel': 0.09708777777732278, 'max_depth': 12, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'iterations': 290, 'subsample': 0.6218113649276331}. Best is trial 63 with value: 0.2525475514465152.
# [I 2026-01-12 00:30:55,463] Trial 66 finished with value: 0.27335256325224155 and parameters: {'learning_rate': 0.24879411312758942, 'colsample_bylevel': 0.09031880870116975, 'max_depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 298, 'subsample': 0.45456199953685084}. Best is trial 63 with value: 0.2525475514465152.
# [I 2026-01-12 00:30:56,262] Trial 67 finished with value: 0.3936065969755179 and parameters: {'learning_rate': 0.23881460385170045, 'colsample_bylevel': 0.05103730262326475, 'max_depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'iterations': 299, 'bagging_temperature': 7.465686173286495}. Best is trial 63 with value: 0.2525475514465152.
# [I 2026-01-12 00:30:57,109] Trial 68 finished with value: 0.3212782347851711 and parameters: {'learning_rate': 0.12308382012718981, 'colsample_bylevel': 0.08652794819249718, 'max_depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 293, 'subsample': 0.4636076775299143}. Best is trial 63 with value: 0.2525475514465152.
# [I 2026-01-12 00:30:58,060] Trial 69 finished with value: 0.2810369001706794 and parameters: {'learning_rate': 0.26344873777549505, 'colsample_bylevel': 0.09071657516616875, 'max_depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 284, 'subsample': 0.7155747184840162}. Best is trial 63 with value: 0.2525475514465152.
# [I 2026-01-12 00:31:01,202] Trial 70 finished with value: 0.2827021391858384 and parameters: {'learning_rate': 0.291821155261946, 'colsample_bylevel': 0.0909442579724464, 'max_depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 283, 'subsample': 0.6972344645873947}. Best is trial 63 with value: 0.2525475514465152.
# [I 2026-01-12 00:31:02,558] Trial 71 finished with value: 0.2965997425749138 and parameters: {'learning_rate': 0.29766650085740604, 'colsample_bylevel': 0.09125934308634377, 'max_depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 280, 'subsample': 0.7012333435617727}. Best is trial 63 with value: 0.2525475514465152.
# [I 2026-01-12 00:31:03,597] Trial 72 finished with value: 0.25442548637983553 and parameters: {'learning_rate': 0.25347804791259815, 'colsample_bylevel': 0.0906648659754824, 'max_depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 296, 'subsample': 0.7581910221010169}. Best is trial 63 with value: 0.2525475514465152.
# [I 2026-01-12 00:31:04,532] Trial 73 finished with value: 0.25227587911815824 and parameters: {'learning_rate': 0.2637536595312491, 'colsample_bylevel': 0.0912597366020109, 'max_depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 299, 'subsample': 0.7529513427664147}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:05,460] Trial 74 finished with value: 0.2709651424157416 and parameters: {'learning_rate': 0.2477216905662417, 'colsample_bylevel': 0.09052329542869345, 'max_depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 300, 'subsample': 0.7603101439336476}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:06,492] Trial 75 finished with value: 0.2817878460881867 and parameters: {'learning_rate': 0.2518482119781301, 'colsample_bylevel': 0.08711808561621825, 'max_depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'iterations': 299}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:07,399] Trial 76 finished with value: 0.26470017969239645 and parameters: {'learning_rate': 0.18446313250472804, 'colsample_bylevel': 0.09315529029433366, 'max_depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 294, 'subsample': 0.7706489422867058}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:08,235] Trial 77 finished with value: 0.26290116500582905 and parameters: {'learning_rate': 0.1753230482207946, 'colsample_bylevel': 0.09010385668967497, 'max_depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 294, 'subsample': 0.8074382696055563}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:08,901] Trial 78 finished with value: 0.4193962319003676 and parameters: {'learning_rate': 0.18248035420071176, 'colsample_bylevel': 0.04541740912967021, 'max_depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 294, 'subsample': 0.845712676085769}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:09,786] Trial 79 finished with value: 0.2738891851909039 and parameters: {'learning_rate': 0.17498970328592126, 'colsample_bylevel': 0.09712273068342796, 'max_depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 295, 'subsample': 0.8881358870098899}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:10,651] Trial 80 finished with value: 0.30499697285829386 and parameters: {'learning_rate': 0.16600605212427585, 'colsample_bylevel': 0.0941040202440939, 'max_depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 299, 'subsample': 0.9134647133127121}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:11,475] Trial 81 finished with value: 0.28748435485669843 and parameters: {'learning_rate': 0.18943595514605557, 'colsample_bylevel': 0.09645879820064861, 'max_depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 292, 'subsample': 0.7559957643987363}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:12,704] Trial 82 finished with value: 0.2898990665952872 and parameters: {'learning_rate': 0.24852541168280523, 'colsample_bylevel': 0.09319950373681046, 'max_depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 291, 'subsample': 0.8763192819546592}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:14,479] Trial 83 finished with value: 0.32008577201056326 and parameters: {'learning_rate': 0.12569081061030343, 'colsample_bylevel': 0.08883143363886094, 'max_depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 300, 'subsample': 0.7702810818309647}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:15,345] Trial 84 finished with value: 0.2972928213056542 and parameters: {'learning_rate': 0.18444744561125315, 'colsample_bylevel': 0.08601887209262317, 'max_depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 268, 'subsample': 0.8202121315180428}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:16,179] Trial 85 finished with value: 0.2885459617916237 and parameters: {'learning_rate': 0.15954421165273208, 'colsample_bylevel': 0.09293064069841162, 'max_depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 280, 'subsample': 0.7514254812089701}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:17,190] Trial 86 finished with value: 0.733385346086848 and parameters: {'learning_rate': 0.010466390823424635, 'colsample_bylevel': 0.09796230339458578, 'max_depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'iterations': 295, 'bagging_temperature': 2.8495436988401415}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:18,010] Trial 87 finished with value: 0.2962048135787126 and parameters: {'learning_rate': 0.19906849414845715, 'colsample_bylevel': 0.08971875788248786, 'max_depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 284, 'subsample': 0.8738129775415928}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:18,913] Trial 88 finished with value: 0.26283580572295495 and parameters: {'learning_rate': 0.2523468112018447, 'colsample_bylevel': 0.0968862138228358, 'max_depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'iterations': 276}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:19,494] Trial 89 finished with value: 0.2825078662782811 and parameters: {'learning_rate': 0.24871399779887535, 'colsample_bylevel': 0.09791350985879653, 'max_depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'iterations': 167}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:20,471] Trial 90 finished with value: 0.34247927039592535 and parameters: {'learning_rate': 0.10581820367484569, 'colsample_bylevel': 0.0925673551341704, 'max_depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'iterations': 294}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:21,390] Trial 91 finished with value: 0.297651411042386 and parameters: {'learning_rate': 0.2559203189894529, 'colsample_bylevel': 0.09606327110681649, 'max_depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'iterations': 273}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:22,298] Trial 92 finished with value: 0.3118675941135363 and parameters: {'learning_rate': 0.198220415756943, 'colsample_bylevel': 0.08733242654263196, 'max_depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'iterations': 288}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:23,191] Trial 93 finished with value: 0.3026102357153094 and parameters: {'learning_rate': 0.15995649528927916, 'colsample_bylevel': 0.09089569923354236, 'max_depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'iterations': 277}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:23,916] Trial 94 finished with value: 0.253054890703525 and parameters: {'learning_rate': 0.2330783541077277, 'colsample_bylevel': 0.0946421562807014, 'max_depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 266, 'subsample': 0.8217698870637078}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:24,901] Trial 95 finished with value: 0.27478437438759173 and parameters: {'learning_rate': 0.26512072005953574, 'colsample_bylevel': 0.09531162414247024, 'max_depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 300, 'subsample': 0.929854680075345}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:26,520] Trial 96 finished with value: 0.4781836745351531 and parameters: {'learning_rate': 0.026707221562792576, 'colsample_bylevel': 0.09838560029237296, 'max_depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 267, 'subsample': 0.6635639394925077}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:27,803] Trial 97 finished with value: 0.305878552722807 and parameters: {'learning_rate': 0.13760084097311936, 'colsample_bylevel': 0.09396862087498684, 'max_depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 285, 'subsample': 0.9910617956145971}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:28,583] Trial 98 finished with value: 0.2928523551837792 and parameters: {'learning_rate': 0.2352165797637249, 'colsample_bylevel': 0.09235698668553131, 'max_depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'iterations': 257, 'subsample': 0.8321222207910944}. Best is trial 73 with value: 0.25227587911815824.
# [I 2026-01-12 00:31:29,499] Trial 99 finished with value: 1.3118277416142905 and parameters: {'learning_rate': 0.0011442822816296325, 'colsample_bylevel': 0.08477008446455042, 'max_depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'iterations': 289}. Best is trial 73 with value: 0.25227587911815824.

# %% [markdown]
# ### Training using best params

# %%
# ----------------------------------------------
# Model training using best parameters
# ----------------------------------------------

# Best parameters
best_params = study.best_params

# Training
model = CatBoostRegressor(**best_params)
model.fit(train_valid_data[feature_names], train_valid_data[target_name], verbose = 0)

# %% [markdown]
# ### Evaluation

# %%
# ----------------------------------------------
# Categoty encoding of test dataset
# ----------------------------------------------
for col, enc in categorical_encoders.items():
    test_data[col+'_encoded'] = enc.transform(test_data[col])

# %%
# ----------------------------------------------
# Model evaluation by test data
# ----------------------------------------------

# Prediction (train)
y_pred_train = model.predict(train_valid_data[feature_names])

# Prediction (Test)
y_pred_test = model.predict(test_data[feature_names])

# Plot
plt.scatter(y_pred_train, train_valid_data[target_name].values.ravel(), s=10, color='k', alpha=0.3)
plt.scatter(y_pred_test, test_data[target_name].values.ravel(), s=10, color='r', alpha=0.3)
plt.plot([y_pred_train.min(), y_pred_train.max()], [y_pred_train.min(), y_pred_train.max()], color='b')
plt.xlabel('Prediction')
plt.ylabel('Actual')
plt.show()

# Metrics
RMSE_train = mean_squared_error(y_true = train_valid_data[target_name].values.ravel(), y_pred = y_pred_train)
RMSE_test = mean_squared_error(y_true = test_data[target_name].values.ravel(), y_pred = y_pred_test)
print(f'Train RMSE: {RMSE_train:.5f}')
print(f'Test RMSE: {RMSE_test:.5f}')
# Out:
# Train RMSE: 0.25688
# Test RMSE: 0.29521

# %% [markdown]
# ### SHAP explanation

# %%
# ----------------------------------------------
# Shap value calculation
# ----------------------------------------------
explainer = shap.TreeExplainer(model)
shape_values = explainer.shap_values(train_valid_data[feature_names])

# %%
# ----------------------------------------------
# Plot 1
# ----------------------------------------------
shap.summary_plot(
    shap_values=shape_values,
    features=train_valid_data[feature_names],
    feature_names=feature_names
)

# %%
# ----------------------------------------------
# Plot 2
# ----------------------------------------------
shap.summary_plot(
    shap_values=shape_values,
    features=train_valid_data[feature_names],
    feature_names=feature_names,
    plot_type = 'bar'
)

# %%
# ----------------------------------------------
# Plot 3
# ----------------------------------------------

fig, ax = plt.subplots(2, 5, figsize = (30, 7))
ax = ax.ravel()
for i, feature_name in enumerate(feature_names):
    ax[i].scatter(train_valid_data[feature_names].values[:,i], shape_values[:,i], s = 10)
    ax[i].set_xlabel(feature_name, fontsize = 9)
    ax[i].set_ylabel('SHAP value', fontsize = 9)
